# %%
import os
import shutil
import glob
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/RnBead_methylation/Sample_annotation.csv', index_col=0)
df = df.rename(columns={'Array': 'Sentrix_Position', 'Slide': 'Sentrix_ID'})
df.reset_index(inplace=True)   
# df.to_csv('../Dataset/RnBead_methylation/Sample_annotation.csv')
df
# Out:
#     index    Sample_ID Sample_Well                         Sample_Plate  \
# 0       1  FIN13295A89         A12  207881760004_R01C01_FIN13295A89_A12
# 1       2  FIN13295A90         B12  207881760004_R02C01_FIN13295A90_B12
# 2       3  FIN13295A91         C12  207881760004_R03C01_FIN13295A91_C12
# 3       4  FIN13295A92         D12  207881760004_R04C01_FIN13295A92_D12
# 4       5  FIN13295A93         E12  207881760004_R05C01_FIN13295A93_E12
# ..    ...          ...         ...                                  ...
# 91     92  FIN13295A68          D9   207881760129_R04C01_FIN13295A68_D9
# 92     93  FIN13295A69          E9   207881760129_R05C01_FIN13295A69_E9
# 93     94  FIN13295A70          F9   207881760129_R06C01_FIN13295A70_F9
# 94     95  FIN13295A71          G9   207881760129_R07C01_FIN13295A71_G9
# 95     96  FIN13295A72          H9   207881760129_R08C01_FIN13295A72_H9
#
#    Sample_Name  Pool_ID            Sample_Group I.D.Code  \
# 0      I_D_102      NaN  Diffuse midline glioma  I-D-102
# 1      I_D_103      NaN  Diffuse midline glioma  I-D-103
# 2      I_D_104      NaN  Diffuse midline glioma  I-D-104
# 3      I_D_105      NaN  Diffuse midline glioma  I-D-105
# 4      I_D_106      NaN  Diffuse midline glioma  I-D-106
# ..         ...      ...                     ...      ...
# 91     I_D_071      NaN  Diffuse midline glioma  I-D-071
# 92     I_D_074      NaN  Diffuse midline glioma  I-D-074
# 93     I_D_076      NaN  Diffuse midline glioma  I-D-076
# 94     I_D_078      NaN  Diffuse midline glioma  I-D-078
# 95     I_D_079      NaN  Diffuse midline glioma  I-D-079
#
#                      Sample Sample.Type Tumour.Normal   Collection  \
# 0                SU-DIPG-17   Cell-line        Tumour  Post-mortem
# 1                     RA055   Cell-line        Tumour  Progression
# 2                    PBT-28   Cell-line        Tumour    Diagnosis
# 3                   P002306   Cell-line        Tumour      Unknown
# 4                   P007601   Cell-line        Tumour      Unknown
# ..                      ...         ...           ...          ...
# 91              VUMC-DIPG-A   Cell-line        Tumour      Unknown
# 92  UON-JEM7-Pons-cell line   Cell-line        Tumour  Post-mortem
# 93                SU-DIPG43   Cell-line        Tumour      Unknown
# 94                SU-DIPG36   Cell-line        Tumour      Unknown
# 95                SU-DIPG33   Cell-line        Tumour      Unknown
#
#                      Institution Sentrix_Position    Sentrix_ID  \
# 0            Stanford Univeristy           R01C01  207881760004
# 1          Zero Childhood Cancer           R02C01  207881760004
# 2    Seattle Children's Hospital           R03C01  207881760004
# 3          Zero Childhood Cancer           R04C01  207881760004
# 4          Zero Childhood Cancer           R05C01  207881760004
# ..                           ...              ...           ...
# 91  VU University Medical Center           R04C01  207881760129
# 92       University of Newcastle           R05C01  207881760129
# 93           Stanford Univeristy           R06C01  207881760129
# 94           Stanford Univeristy           R07C01  207881760129
# 95           Stanford Univeristy           R08C01  207881760129
#
#                                              Basename
# 0   ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 1   ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 2   ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 3   ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 4   ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# ..                                                ...
# 91  ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 92  ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 93  ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 94  ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
# 95  ../Dataset/Izac_Methylomics/FIN13296/iDAT/2078...
#
# [96 rows x 16 columns]

# %%
# Base directory containing the files
base_directory = '../Dataset/Methylomics/FIN13296/iDAT'

for batch in os.listdir(base_directory):
    tmp_directory = os.path.join(base_directory, batch) 
    if batch != '.DS_Store':
        # Get all file paths starting with '207881760004' in the base directory
        file_paths = glob.glob(f'{tmp_directory}/*')

        # Iterate through each file path
        for file_path in file_paths:
            # Extract the filename from the path
            filename = os.path.basename(file_path)
            
            # Check if the filename contains more than one underscore
            if filename.count('_') > 1:
                # Extract the first two parts of the filename
                subfolder_name = filename.split('_')[0] + '_' + filename.split('_')[1]
                
                # Create the subfolder path
                subfolder_path = os.path.join(tmp_directory, subfolder_name)
                
                # Check if the file is already in a subgrouped folder
                if not os.path.dirname(file_path).endswith(subfolder_name):
                    # Create the subfolder if it doesn't exist
                    os.makedirs(subfolder_path, exist_ok=True)
                    
                    # Move the file to the subfolder
                    shutil.move(file_path, os.path.join(subfolder_path, filename))
                else:
                    print(f"File '{filename}' is already in the subgrouped folder '{subfolder_name}' and will be skipped.")
            else:
                print(f"Filename '{filename}' does not contain more than one underscore and will be skipped.")

        print("Files have been organized into subfolders.")

# %%
df = pd.read_csv('../Dataset/Methylomics/FIN13296/FIN13296_Infinium_EPIC_SampleSheet.csv').iloc[6:, :]

# Use the first row as column names
df.columns = df.iloc[0]

# Remove the first row
df = df.iloc[1:]

df['Sample_Group'] = df['Sentrix_ID'] + '_' + df['Sentrix_Position']

# Reset the index
df = df.reset_index(drop=True)

df.head(10)
# Out:
# 6    Sentrix_ID Sentrix_Position    Sample_ID Sample_Well  \
# 0  207881760108           R01C01   FIN13295A1          A1
# 1  207881760108           R02C01   FIN13295A2          B1
# 2  207881760108           R03C01   FIN13295A3          C1
# 3  207881760108           R04C01   FIN13295A4          D1
# 4  207881760108           R05C01   FIN13295A5          E1
# 5  207881760108           R06C01   FIN13295A6          F1
# 6  207881760108           R07C01   FIN13295A7          G1
# 7  207881760108           R08C01   FIN13295A8          H1
# 8  207881760123           R01C01   FIN13295A9          A2
# 9  207881760123           R02C01  FIN13295A10          B2
#
# 6                        Sample_Plate  Sample_Name Pool_ID  \
# 0   207881760108_R01C01_FIN13295A1_A1  I_D_001_DNA     NaN
# 1   207881760108_R02C01_FIN13295A2_B1  I_D_002_DNA     NaN
# 2   207881760108_R03C01_FIN13295A3_C1  I_D_003_DNA     NaN
# 3   207881760108_R04C01_FIN13295A4_D1  I_D_004_DNA     NaN
# 4   207881760108_R05C01_FIN13295A5_E1  I_D_005_DNA     NaN
# 5   207881760108_R06C01_FIN13295A6_F1  I_D_006_DNA     NaN
# 6   207881760108_R07C01_FIN13295A7_G1  I_D_007_DNA     NaN
# 7   207881760108_R08C01_FIN13295A8_H1  I_D_008_DNA     NaN
# 8   207881760123_R01C01_FIN13295A9_A2  I_D_009_DNA     NaN
# 9  207881760123_R02C01_FIN13295A10_B2  I_D_010_DNA     NaN
#
# 6         Sample_Group
# 0  207881760108_R01C01
# 1  207881760108_R02C01
# 2  207881760108_R03C01
# 3  207881760108_R04C01
# 4  207881760108_R05C01
# 5  207881760108_R06C01
# 6  207881760108_R07C01
# 7  207881760108_R08C01
# 8  207881760123_R01C01
# 9  207881760123_R02C01

# %%
# Grouping by Sentrix_ID and saving to different dataframes
dfs = {}
for sentrix_id, group in df.groupby('Sentrix_ID'):
    dfs[sentrix_id] = group

# Saving each dataframe to a separate file
for sentrix_id, df_group in dfs.items():
    filename = f"{base_directory}/{sentrix_id}_Sample_Sheet.csv"
    df_group.to_csv(filename, index=False)

# %%
# Base directory containing the files
base_directory = '../Dataset/Methylomics/FIN13296/iDAT'


for batch in os.listdir(base_directory):
    if batch != '.DS_Store':
        if not batch.endswith('.csv'):
            src_path = f'{base_directory}/{batch}_Sample_Sheet.csv'
            target_path = f'{base_directory}/{batch}/Sample_Sheet.csv'
            # Move the file to the subfolder
            shutil.move(src_path, target_path)
